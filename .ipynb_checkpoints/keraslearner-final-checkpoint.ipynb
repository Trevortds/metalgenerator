# %% [markdown]
# ## Initializing stuff
#
# Changes: adding word tokenize, making the "chars" vector contain words rather than actual chars. Yes, this is confusing, but hopefully if I say it right up front it won't be so bad.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, SimpleRNN
from keras.layers.wrappers import TimeDistributed
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import cmudict
import sys
import re
from sklearn.preprocessing import normalize


pronouncing_dict = cmudict.dict()
def nsyl(word):
    if word not in pronouncing_dict:
        if re.search('\W', word):
            # if the word has non-word characters
            return 0
        else:
            # take a guess: number of vowels
            return len(re.findall("[aeiou]", x))
    return [len(list(y for y in x if y[-1].isdigit())) for x in pronouncing_dict[word.lower()]][0]


# I'm making this from Trung Tran's LSTM tutorial. 
# I'm going to try to annotate it in my own words so that I can understand what's happening
# And then change it to do what I want. 

data = []
avgsyllables = 0
linecount = 0

with open("lyrics.txt", 'r') as f:
    for line in f:
        
        for word in word_tokenize(line):
            data.append(word.lower())
            avgsyllables += nsyl(word)
        linecount += 1
        data.append("\n") # I want the machine to learn newlines
        # since they're part of the lyrics
        # and have similar meaning to words. 

avgsyllables = avgsyllables / linecount
data = data[:1000]        

# features. This will eventually be words
# also, this line is what killed my results. I trained a model for a full day
# it was performing great. 
chars = sorted(list(set(data)))

# %% [markdown]
# ## Preparing data
#
# Only change here is the len_sequence. I made it 700 words, it'll be learning from multiple songs at once.

# %%
# conversion to numbers. This is actually a really clever solution
ix_to_char = {ix:char for ix, char in enumerate(chars)}
char_to_ix = {char:ix for ix, char in enumerate(chars)}

# setting up parameters. 
num_features = len(chars)
# length of the group of words that the lstm will be shown at a time
len_sequence = 70
num_sequences = len(data)//len_sequence


# need input and output tapes for the LSTM
X = np.zeros((len(data)//len_sequence, len_sequence, num_features))
y = np.zeros((len(data)//len_sequence, len_sequence, num_features))

# for each of the sequences
for i in range(0, len(data)//len_sequence):
    # select the characters in the data that correspond to this sequence
    X_sequence = data[i*len_sequence:(i+1)*len_sequence]
    # convert to numeric
    X_sequence_ix = [char_to_ix[value] for value in X_sequence]
    #initialize 
    input_sequence = np.zeros((len_sequence, num_features))
    for j in range(len_sequence):
        #make a 1-hot vector for each of the letters the lstm is being shown
        input_sequence[j][X_sequence_ix[j]] = 1

    X[i] = input_sequence
    
    # select targets: the symbol that follows
    y_sequence = data[i*len_sequence+1:(i+1)*len_sequence+1]
    # convert to numeric
    y_sequence_ix = [char_to_ix[value] for value in y_sequence]
    target_sequence = np.zeros((len_sequence, num_features))
    for j in range(len_sequence):
        target_sequence[j][y_sequence_ix[j]] = 1
        
    y[i] = target_sequence

# %% [markdown]
# ## Setting up network
#
# Taking cues from Tran, I set it up to have 700 hidden states, with 0.3 dropout at the first layer and three layers

# %%
# initialize a sequential network
model = Sequential()

hidden_dim = 700
layer_num = 3

# add an initial lstm layer
# I don't know why the input shape needs to be a tuple
# the return-sequences parameter makes it give you multiple outputs
model.add(LSTM(hidden_dim, 
               input_shape=(None, num_features), 
               return_sequences=True))
model.add(Dropout(0.3))

# add more layers
# I don't really know what adding a layer to an LSTM means, 
#  they're only ever shown with one.

for i in range(layer_num-1):
    model.add(LSTM(hidden_dim, return_sequences=True))

# I don't see why the dense layer is necessary, but Tran says it is.
# and in order to get the dense layer to work, a time distributed layer
#  needs to go between.

model.add(TimeDistributed(Dense(num_features)))

# pick an activation for this layer
model.add(Activation('softmax'))

# pick a loss function and optimization method. 

model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %% [markdown]
# ## Heuristic
#
# This is the part where I get to be creative.

# %%
def random_pick(model_predictions):
    # Select random character from the best ten
    candidates = np.argpartition(model_predictions[0,0], -10)[-10:]
    return [np.random.choice(candidates)]
    

def softmax_pick(model_predictions):
    return [np.random.choice(model_predictions.shape[2], p=model_predictions[0,0])]



def beam_search(model_predictions, history, i):
    # Select the character most likely to lead down a good path
    best_ix = 0
    candidates = np.argpartition(model_predictions[0,-1], -10)[-10:]
#     print(model_predictions.shape) (1, 1, numfeatures)
    print(np.argmax(model_predictions[0], 1))
    print(candidates)
    candidate_predictions = [model_predictions[0, -1, c] for c in candidates]
    print(candidate_predictions)
#     print(normalize(np.asarray([candidate_predictions])))
    
    h = np.zeros(len(candidates))
    
    for i in range(len(candidates)):
        candidate = candidates[i]
        pred = candidate_predictions[i]
        word = ix_to_char[candidate]
        print("candidate: {} score: {} word:{}".format(candidate, model_predictions[0,0,candidate], word))

        h[i] = heuristic(history, word, pred)
        print("adjucted score: ", h[i])
#         if score < best_score:
#             best_score = score
#             best_candidate = candidate
    print("scores: ", h)
    # softmax preserves ranking but squishes values
    # temperature lets you play with how far the values change
    # if > 1 rank 1 is further from rank 2
    # if < 1 rank 1 is closer to rank 2
    h = softmax(h, 0.4) # 0 is 
    print("softmax scores: ", h)
    return [np.random.choice(candidates, p=h)]
    
#     return [best_candidate]
#     return np.argmax(model_predictions[0], 1)

def heuristic(history, word, prediction):
    # don't give more than two newlines in a row. 
    # maximizing heuristic
    if word == '\n' and len(history) > 1 and history[-2] == '\n':
        return 1000
    
    line = []
    syl_count = 0
    for back_word in history[::-1]:
        if back_word == '\n':
            break
        else:
            syl_count = nsyl(back_word)
            line.insert(0, back_word)
    syl_count += nsyl(word)
    print("syllable count ", syl_count)
    # return square difference between number 
    # of syllables in the sentence and the average
    # this may cause a preference for long words at the beginning
    # we'll see. 
    
    return prediction * (syl_count - avgsyllables)**-2
    

# copied from http://stackoverflow.com/questions/41902047/how-to-calculate-robust-softmax-function-with-temperature?noredirect=1&lq=1
def softmax(x, tau):
    """ Returns softmax probabilities with temperature tau
        Input:  x -- 1-dimensional array
        Output: s -- 1-dimensional array
    """
    e_x = np.exp(x / tau)
    return e_x / e_x.sum()

# %%
x = softmax(np.asarray([5., 6., 7.]), 1)
print(x)
for i in range(10):
    x = softmax(x, 1)
    print(x)
# Out:
# [ 0.09003057  0.24472847  0.66524096]
# [ 0.25349765  0.29590914  0.4505932 ]
# [ 0.30663709  0.31992174  0.37344117]
# [ 0.32441629  0.3287548   0.34682891]
# [ 0.33035861  0.33179499  0.33784641]
# [ 0.33234148  0.33281919  0.33483933]
# [ 0.33300268  0.3331618   0.33383551]
# [ 0.33322311  0.33327614  0.33350075]
# [ 0.33329659  0.33331427  0.33338914]
# [ 0.33332109  0.33332698  0.33335194]
# [ 0.33332925  0.33333121  0.33333953]

# %%
model.fit(X, y, batch_size=batch_size, verbose=1, nb_epoch=1)
generate_text(model, 30)
# Out:
# Epoch 1/1
# 14/14 [==============================] - 4s - loss: 4.1368
# ix:  [221]
# will [164]
# [165 109 305 112 176 285 144 164 239 284]
# [0.020216838, 0.024085596, 0.029399427, 0.028467134, 0.024950704, 0.021158284, 0.02549744, 0.032174785, 0.021520717, 0.026738945]
# candidate: 165 score: 0.020216837525367737 word:,
# syllable count  1
# adjucted score:  0.00264368911049
# candidate: 109 score: 0.024085596203804016 word:save
# syllable count  2
# adjucted score:  0.0077284365037
# candidate: 305 score: 0.02939942665398121 word:thee
# syllable count  2
# adjucted score:  0.00943350541202
# candidate: 112 score: 0.02846713364124298 word:
#
# syllable count  1
# adjucted score:  0.0037225531006
# candidate: 176 score: 0.024950703606009483 word:spring
# syllable count  2
# adjucted score:  0.00800602679336
# candidate: 285 score: 0.021158283576369286 word:went
# syllable count  2
# adjucted score:  0.00678913861063
# candidate: 144 score: 0.0254974402487278 word:their
# syllable count  2
# adjucted score:  0.00818146025125
# candidate: 164 score: 0.03217478469014168 word:me
# syllable count  2
# adjucted score:  0.0103240450597
# candidate: 239 score: 0.021520717069506645 word:need
# syllable count  2
# adjucted score:  0.00690543401867
# candidate: 284 score: 0.02673894539475441 word:revenge
# syllable count  3
# adjucted score:  0.0456472492491
# scores:  [ 0.00264369  0.00772844  0.00943351  0.00372255  0.00800603  0.00678914
#   0.00818146  0.01032405  0.00690543  0.04564725]
# softmax scores:  [ 0.09576293  0.09822879  0.09906981  0.0962809   0.09836523  0.09776854
#   0.09845155  0.09951192  0.09782541  0.11873492]
# me [164 112]
# [238 186  49  90 239 214 285 164 165 112]
# [0.039036959, 0.04093511, 0.04167204, 0.061434761, 0.071032159, 0.070012644, 0.070161432, 0.1091605, 0.059345737, 0.15128256]
# candidate: 238 score: 0.01767590269446373 word:storm
# syllable count  2
# adjucted score:  0.0125259370597
# candidate: 186 score: 0.01859152689576149 word:the
# syllable count  2
# adjucted score:  0.0131350039274
# candidate: 49 score: 0.018599551171064377 word:n't
# syllable count  1
# adjucted score:  0.00544931508859
# candidate: 90 score: 0.019471336156129837 word:all
# syllable count  2
# adjucted score:  0.0197128044119
# candidate: 239 score: 0.021520722657442093 word:need
# syllable count  2
# adjucted score:  0.0227923579779
# candidate: 214 score: 0.01814015954732895 word:cries
# syllable count  2
# adjucted score:  0.0224652223061
# candidate: 285 score: 0.021158285439014435 word:went
# syllable count  2
# adjucted score:  0.0225129645057
# candidate: 164 score: 0.03217480704188347 word:me
# syllable count  2
# adjucted score:  0.0350267424855
# candidate: 165 score: 0.020216843113303185 word:,
# syllable count  1
# adjucted score:  0.00776044614929
# candidate: 112 score: 0.028467122465372086 word:
#
# syllable count  1
# adjucted score:  0.0197827215082
# scores:  [ 0.01252594  0.013135    0.00544932  0.0197128   0.02279236  0.02246522
#   0.02251296  0.03502674  0.00776045  0.01978272]
# softmax scores:  [ 0.09716113  0.09745747  0.09378338  0.10071604  0.10227884  0.10211168
#   0.10213606  0.10873076  0.09487339  0.10075125]
# all [164 112 112]
# [ 90 249 214 122 126  15 222 112  64 197]
# [0.017229613, 0.019879382, 0.020232657, 0.022175161, 0.027145086, 0.05637414, 0.12912473, 0.39569974, 0.072394557, 0.11578729]
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00552853117205
# candidate: 249 score: 0.009046700783073902 word:go
# syllable count  2
# adjucted score:  0.00637877264989
# candidate: 214 score: 0.018140161409974098 word:cries
# syllable count  2
# adjucted score:  0.00649212929485
# candidate: 122 score: 0.010790013708174229 word:trust
# syllable count  2
# adjucted score:  0.00711542797595
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.00871014653957
# candidate: 15 score: 0.010433207266032696 word:one
# syllable count  2
# adjucted score:  0.0180889839056
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.041432741577
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0517443487842
# candidate: 64 score: 0.01081289816647768 word:your
# syllable count  2
# adjucted score:  0.0232295158713
# candidate: 197 score: 0.011124697513878345 word:by
# syllable count  2
# adjucted score:  0.0371531064214
# scores:  [ 0.00552853  0.00637877  0.00649213  0.00711543  0.00871015  0.01808898
#   0.04143274  0.05174435  0.02322952  0.03715311]
# softmax scores:  [ 0.09243545  0.09282925  0.09288188  0.0931718   0.09391768  0.09842677
#   0.11061234  0.11646487  0.10098939  0.10827058]
# cries [164 112 112 112]
# [ 64  15 205 217 126 123 222 197 273 112]
# [0.011892232, 0.012303706, 0.016239345, 0.0561512, 0.035189178, 0.07105159, 0.038153436, 0.025077524, 0.076348007, 0.62158722]
# candidate: 64 score: 0.01081289816647768 word:your
# syllable count  2
# adjucted score:  0.00381590557243
# candidate: 15 score: 0.010433207266032696 word:one
# syllable count  2
# adjucted score:  0.00394793684053
# candidate: 205 score: 0.007157350890338421 word:him
# syllable count  2
# adjucted score:  0.00521078017757
# candidate: 217 score: 0.00654649967327714 word:like
# syllable count  2
# adjucted score:  0.0180174483039
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0112912848102
# candidate: 123 score: 0.0060858107171952724 word:nightfall
# syllable count  3
# adjucted score:  0.121295346432
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.0122424375672
# candidate: 197 score: 0.011124697513878345 word:by
# syllable count  2
# adjucted score:  0.00804672002571
# candidate: 273 score: 0.005331032909452915 word:speeches
# syllable count  3
# adjucted score:  0.130337095993
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0812829085834
# scores:  [ 0.00381591  0.00394794  0.00521078  0.01801745  0.01129128  0.12129535
#   0.01224244  0.00804672  0.1303371   0.08128291]
# softmax scores:  [ 0.08104645  0.08109997  0.08161367  0.08701061  0.08413303  0.1458268
#   0.0845341   0.08277917  0.15257074  0.11938546]
# i [164 112 112 112 112]
# [ 77  66 186 123 217 126 223 273 192 112]
# [0.0053466647, 0.0096223811, 0.0116354, 0.024934409, 0.027498474, 0.10131398, 0.066542193, 0.011912837, 0.015184239, 0.68981469]
# candidate: 77 score: 0.002784326206892729 word:immortal
# syllable count  4
# adjucted score:  0.0971119745581
# candidate: 66 score: 0.0033230572007596493 word:until
# syllable count  3
# adjucted score:  0.0164267969634
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0037334949933
# candidate: 123 score: 0.0060858107171952724 word:nightfall
# syllable count  3
# adjucted score:  0.0425666448022
# candidate: 217 score: 0.00654649967327714 word:like
# syllable count  2
# adjucted score:  0.00882353964264
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0325090000943
# candidate: 223 score: 0.011472643353044987 word:a
# syllable count  2
# adjucted score:  0.0213516456614
# candidate: 273 score: 0.005331032909452915 word:speeches
# syllable count  3
# adjucted score:  0.020336936172
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  1
# adjucted score:  0.00198559287651
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0902047896165
# scores:  [ 0.09711197  0.0164268   0.00373349  0.04256664  0.00882354  0.032509
#   0.02135165  0.02033694  0.00198559  0.09020479]
# softmax scores:  [ 0.1355603   0.09055801  0.0849892   0.10320217  0.08717995  0.09814065
#   0.09281562  0.09234591  0.08424967  0.13095852]
# i [164 112 112 112 112 112]
# [183 139 186 223  66  77 112 280   3 126]
# [0.010572628, 0.019026831, 0.04543915, 0.048738167, 0.064698867, 0.10341842, 0.31141108, 0.098160774, 0.090353742, 0.11746524]
# candidate: 183 score: 0.0031367079354822636 word:have
# syllable count  2
# adjucted score:  0.00339247923931
# candidate: 139 score: 0.00490149250254035 word:my
# syllable count  2
# adjucted score:  0.0061052112807
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0145802322687
# candidate: 223 score: 0.011472643353044987 word:a
# syllable count  2
# adjucted score:  0.0156388001934
# candidate: 66 score: 0.0033230572007596493 word:until
# syllable count  3
# adjucted score:  0.110450329559
# candidate: 77 score: 0.002784326206892729 word:immortal
# syllable count  4
# adjucted score:  1.87839859184
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.04072219937
# candidate: 280 score: 0.0028829139191657305 word:'ve
# syllable count  1
# adjucted score:  0.0128361603389
# candidate: 3 score: 0.0024824312422424555 word:shadow
# syllable count  3
# adjucted score:  0.154246913325
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0376915174635
# scores:  [ 0.00339248  0.00610521  0.01458023  0.0156388   0.11045033  1.87839859
#   0.0407222   0.01283616  0.15424691  0.03769152]
# softmax scores:  [  8.47336497e-05   8.58907778e-05   8.96086243e-05   9.00841657e-05
#    1.44720176e-04   9.99033276e-01   1.02121308e-04   8.88306021e-05
#    1.80149124e-04   1.00585488e-04]
# immortal [164 112 112 112 112 112 112]
# [126 172  77 280  52 212   8 112   3 186]
# [0.031803411, 0.044159614, 0.060774133, 0.061439522, 0.064631842, 0.067933455, 0.074559301, 0.14373785, 0.067771003, 0.093189746]
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0102048808164
# candidate: 172 score: 0.0030683483928442 word:know
# syllable count  2
# adjucted score:  0.0141696625011
# candidate: 77 score: 0.002784326206892729 word:immortal
# syllable count  4
# adjucted score:  1.10384629641
# candidate: 280 score: 0.0028829139191657305 word:'ve
# syllable count  1
# adjucted score:  0.00803424343854
# candidate: 52 score: 0.0016577172791585326 word:land
# syllable count  2
# adjucted score:  0.0207386640289
# candidate: 212 score: 0.002223587827757001 word:heard
# syllable count  2
# adjucted score:  0.0217980651111
# candidate: 8 score: 0.001845579594373703 word:which
# syllable count  2
# adjucted score:  0.0239241254287
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0187961245243
# candidate: 3 score: 0.0024824312422424555 word:shadow
# syllable count  3
# adjucted score:  0.115694908837
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0299021468996
# scores:  [ 0.01020488  0.01416966  1.1038463   0.00803424  0.02073866  0.02179807
#   0.02392413  0.01879612  0.11569491  0.02990215]
# softmax scores:  [ 0.00404742  0.00412846  0.95938012  0.00400373  0.00426631  0.00428897
#   0.0043348   0.00422507  0.00685879  0.00446633]
# immortal [164 112 112 112 112 112 112 112]
# [191 306 198 263 112 212   8 186 274  52]
# [0.03158319, 0.035899263, 0.050579462, 0.042759202, 0.1163175, 0.03826151, 0.06145516, 0.070370011, 0.058364719, 0.063737549]
# candidate: 191 score: 0.0017120231641456485 word:world
# syllable count  2
# adjucted score:  0.0101342178187
# candidate: 306 score: 0.0023697044234722853 word:enemy
# syllable count  4
# adjucted score:  0.652041693849
# candidate: 198 score: 0.0014459046069532633 word:covers
# syllable count  3
# adjucted score:  0.0863464614578
# candidate: 263 score: 0.002598334336653352 word:(
# syllable count  1
# adjucted score:  0.00559147975895
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0152104559411
# candidate: 212 score: 0.002223587827757001 word:heard
# syllable count  2
# adjucted score:  0.0122771158084
# candidate: 8 score: 0.001845579594373703 word:which
# syllable count  2
# adjucted score:  0.0197193501376
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0225798920409
# candidate: 274 score: 0.0015841230051591992 word:lies
# syllable count  2
# adjucted score:  0.0187277085528
# candidate: 52 score: 0.0016577172791585326 word:land
# syllable count  2
# adjucted score:  0.0204517087853
# scores:  [ 0.01013422  0.65204169  0.08634646  0.00559148  0.01521046  0.01227712
#   0.01971935  0.02257989  0.01872771  0.02045171]
# softmax scores:  [ 0.02902284  0.71882674  0.04248471  0.02837105  0.0297689   0.02933547
#   0.03044764  0.03088626  0.03029705  0.03055934]
# enemy [164 112 112 112 112 112 112 112 112]
# [215  28 263 219  68 105 112 274 186 198]
# [0.022864103, 0.026365262, 0.026992599, 0.027660744, 0.032449517, 0.032965567, 0.13709444, 0.041779026, 0.062526613, 0.043845825]
# candidate: 215 score: 0.0020751110278069973 word:he
# syllable count  2
# adjucted score:  0.00733649145349
# candidate: 28 score: 0.002198060043156147 word:they
# syllable count  2
# adjucted score:  0.00845992135194
# candidate: 263 score: 0.002598334336653352 word:(
# syllable count  1
# adjucted score:  0.00352973301374
# candidate: 219 score: 0.0015059508150443435 word:down
# syllable count  2
# adjucted score:  0.00887560780668
# candidate: 68 score: 0.0013191920006647706 word:warning
# syllable count  3
# adjucted score:  0.0553960220518
# candidate: 105 score: 0.0027166970539838076 word:take
# syllable count  2
# adjucted score:  0.0105777863635
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0179273871394
# candidate: 274 score: 0.0015841230051591992 word:lies
# syllable count  2
# adjucted score:  0.0134057944799
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0200631513513
# candidate: 198 score: 0.0014459046069532633 word:covers
# syllable count  3
# adjucted score:  0.0748511681397
# scores:  [ 0.00733649  0.00845992  0.00352973  0.00887561  0.05539602  0.01057779
#   0.01792739  0.01340579  0.02006315  0.07485117]
# softmax scores:  [ 0.09229428  0.09281417  0.09055418  0.09300728  0.11736395  0.09380223
#   0.09731339  0.09513802  0.09835815  0.12935435]
# warning [164 112 112 112 112 112 112 112 112 112]
# [218  24 129 194 215  68 105 126 186 112]
# [0.02022724, 0.020284381, 0.021480618, 0.024060506, 0.023981022, 0.021876948, 0.025966303, 0.028792296, 0.063425399, 0.1719645]
# candidate: 218 score: 0.01961112767457962 word:us
# syllable count  2
# adjucted score:  0.00649039125884
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00650872610431
# candidate: 129 score: 0.00163563946262002 word:mine
# syllable count  2
# adjucted score:  0.00689256729267
# candidate: 194 score: 0.0013154003536328673 word:blinded
# syllable count  3
# adjucted score:  0.0410747662364
# candidate: 215 score: 0.0020751110278069973 word:he
# syllable count  2
# adjucted score:  0.00769488129199
# candidate: 68 score: 0.0013191920006647706 word:warning
# syllable count  3
# adjucted score:  0.0373471160264
# candidate: 105 score: 0.0027166970539838076 word:take
# syllable count  2
# adjucted score:  0.00833190615431
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.00923869297217
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0203515481847
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0224872295623
# scores:  [ 0.00649039  0.00650873  0.00689257  0.04107477  0.00769488  0.03734712
#   0.00833191  0.00923869  0.02035155  0.02248723]
# softmax scores:  [ 0.09485992  0.09486861  0.09505086  0.11276693  0.09543293  0.11068462
#   0.09573738  0.09617243  0.10166743  0.1027589 ]
# us [164 112 112 112 112 112 112 112 112 112 112]
# [ 90 126 186  55 112  42 215  24 218 222]
# [0.017563941, 0.039566681, 0.064704292, 0.01828029, 0.18528947, 0.018430889, 0.019189611, 0.021796076, 0.023254484, 0.022417461]
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00563580827702
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0126959107656
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0207619111571
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00586566592988
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0242296926858
# candidate: 42 score: 0.003711926518008113 word:is
# syllable count  2
# adjucted score:  0.0059139890686
# candidate: 215 score: 0.0020751110278069973 word:he
# syllable count  2
# adjucted score:  0.00615744320741
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00699378936229
# candidate: 218 score: 0.01961112767457962 word:us
# syllable count  2
# adjucted score:  0.00746175436232
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00719317580132
# scores:  [ 0.00563581  0.01269591  0.02076191  0.00586567  0.02422969  0.00591399
#   0.00615744  0.00699379  0.00746175  0.00719318]
# softmax scores:  [ 0.09764787  0.10115646  0.10531948  0.09776016  0.10716153  0.09778379
#   0.09790289  0.09831315  0.09854346  0.09841121]
# is [164 112 112 112 112 112 112 112 112 112 112 112]
# [ 55 221  90  24  49 218 222 126 186 112]
# [0.016949365, 0.017645303, 0.021724969, 0.021118412, 0.018730354, 0.018799834, 0.023333766, 0.044840828, 0.063184507, 0.18915652]
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00543860693416
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00566191527527
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00697097315712
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00677634480086
# candidate: 49 score: 0.01859954372048378 word:n't
# syllable count  1
# adjucted score:  0.00244930650953
# candidate: 218 score: 0.01961112767457962 word:us
# syllable count  2
# adjucted score:  0.00603237394496
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.0074871937587
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0143882462292
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0202742522009
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0247353734018
# scores:  [ 0.00543861  0.00566192  0.00697097  0.00677634  0.00244931  0.00603237
#   0.00748719  0.01438825  0.02027425  0.02473537]
# softmax scores:  [ 0.09767525  0.09778437  0.0984265   0.09833076  0.0962262   0.09796566
#   0.09868087  0.10214531  0.10519612  0.10756895]
# in [164 112 112 112 112 112 112 112 112 112 112 112 112]
# [ 55   0  49  90 126 186  24 221 222 112]
# [0.01576581, 0.016067896, 0.01813807, 0.023448393, 0.046446919, 0.062058836, 0.019957086, 0.018879423, 0.02313944, 0.19213727]
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.0050588353081
# candidate: 0 score: 0.0018919747089967132 word:)
# syllable count  1
# adjucted score:  0.00210114572725
# candidate: 49 score: 0.01859954372048378 word:n't
# syllable count  1
# adjucted score:  0.00237185549837
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00752397461702
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0149035990082
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0199130538922
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00640370581639
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00605791195756
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00742483962503
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0251251567345
# scores:  [ 0.00505884  0.00210115  0.00237186  0.00752397  0.0149036   0.01991305
#   0.00640371  0.00605791  0.00742484  0.02512516]
# softmax scores:  [ 0.09764553  0.09621213  0.09634245  0.09885653  0.10257228  0.10517388
#   0.09830435  0.09813453  0.09880754  0.10795079]
# of [164 112 112 112 112 112 112 112 112 112 112 112 112 112]
# [209  49 221  90  55  24 222 126 186 112]
# [0.014909524, 0.015890973, 0.018923206, 0.021982757, 0.016335577, 0.018599037, 0.023392107, 0.046520051, 0.063297182, 0.19377464]
# candidate: 209 score: 0.0031119203194975853 word:you
# syllable count  2
# adjucted score:  0.00478407560253
# candidate: 49 score: 0.01859954372048378 word:n't
# syllable count  1
# adjucted score:  0.00207801004484
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00607196088274
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00705369064185
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.0052416584074
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00596794349179
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00750591410391
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.014927064885
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0203104066968
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0253392701255
# scores:  [ 0.00478408  0.00207801  0.00607196  0.00705369  0.00524166  0.00596794
#   0.00750591  0.01492706  0.02031041  0.02533927]
# softmax scores:  [ 0.09739608  0.09608715  0.09802528  0.09850763  0.09761917  0.09797431
#   0.09873062  0.10246291  0.10525833  0.10793853]
# you [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112]
# [209 243  24 221 126 186 112  90  55 222]
# [0.014373822, 0.01482203, 0.017041709, 0.01841335, 0.048062697, 0.061521925, 0.1893414, 0.01927501, 0.019283963, 0.023768462]
# candidate: 209 score: 0.0031119203194975853 word:you
# syllable count  2
# adjucted score:  0.00461218276545
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00475600076262
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00546823781834
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00590836137016
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0154220596919
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0197407731647
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.02475954938
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00618484536523
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00618771838418
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00762667652747
# scores:  [ 0.00461218  0.004756    0.00546824  0.00590836  0.01542206  0.01974077
#   0.02475955  0.00618485  0.00618772  0.00762668]
# softmax scores:  [ 0.09725167  0.09732162  0.09766882  0.09788399  0.10265271  0.10489345
#   0.10755894  0.0980194   0.09802081  0.09872859]
# the [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112]
# [209  24  55 221  90 243 222 126 186 112]
# [0.013555164, 0.016483426, 0.021665992, 0.017086273, 0.016583234, 0.017849181, 0.023615556, 0.050350301, 0.059088293, 0.18537995]
# candidate: 209 score: 0.0031119203194975853 word:you
# syllable count  2
# adjucted score:  0.00434949667247
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00528909937929
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00695204900508
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00548253716893
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00532112514321
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00572733428124
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00757761287066
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0161560918268
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0189598845832
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0242415244372
# scores:  [ 0.0043495   0.0052891   0.00695205  0.00548254  0.00532113  0.00572733
#   0.00757761  0.01615609  0.01895988  0.02424152]
# softmax scores:  [ 0.09715611  0.09761362  0.09842864  0.09770808  0.09762925  0.09782775
#   0.09873699  0.10306419  0.10451922  0.10731615]
# and [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112]
# [209 243  90 221  24  55 222 126 186 112]
# [0.012861126, 0.019699054, 0.014618561, 0.015546893, 0.016828211, 0.021851713, 0.02361279, 0.052416049, 0.059373531, 0.1826126]
# candidate: 209 score: 0.0031119203194975853 word:you
# syllable count  2
# adjucted score:  0.00412679825769
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00632091003637
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00469071294609
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00498859038337
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00539973182613
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00701164188485
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00757672532477
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0168189362061
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0190514099897
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0238796466566
# scores:  [ 0.0041268   0.00632091  0.00469071  0.00498859  0.00539973  0.00701164
#   0.00757673  0.01681894  0.01905141  0.02387965]
# softmax scores:  [ 0.0970564   0.09812703  0.09733045  0.09747552  0.0976761   0.09846651
#   0.09874511  0.1034153   0.10457613  0.10713144]
# you [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112]
# [209  90 221 243  24  55 222 126 112 186]
# [0.012146155, 0.013410749, 0.014462978, 0.02013969, 0.016675007, 0.021732619, 0.024181398, 0.054791741, 0.17571701, 0.061974496]
# candidate: 209 score: 0.0031119203194975853 word:you
# syllable count  2
# adjucted score:  0.00389738288359
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.00430315781146
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00464079043174
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00646229878754
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00535057254148
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00697342780426
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00775917667084
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0175812335401
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0229779335257
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0198859912132
# scores:  [ 0.00389738  0.00430316  0.00464079  0.0064623   0.00535057  0.00697343
#   0.00775918  0.01758123  0.02297793  0.01988599]
# softmax scores:  [ 0.09694533  0.09714222  0.09730635  0.09819662  0.0976523   0.0984479
#   0.09883544  0.10381044  0.10664974  0.10501365]
# will [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112]
# [209  90  55 112 222 221  24 186 243 126]
# [0.011309233, 0.012442414, 0.021842401, 0.16775279, 0.024761314, 0.01355985, 0.016136345, 0.064206786, 0.020171406, 0.0566542]
# candidate: 209 score: 0.0031119203194975853 word:you
# syllable count  2
# adjucted score:  0.00362883659699
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.0039924444284
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00700865411249
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0219364782912
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.0079452564958
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00435100042027
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.0051777300004
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0206022748208
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00647247538284
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0181788477784
# scores:  [ 0.00362884  0.00399244  0.00700865  0.02193648  0.00794526  0.004351
#   0.00517773  0.02060227  0.00647248  0.01817885]
# softmax scores:  [ 0.09684026  0.09701648  0.09849068  0.10612324  0.09895299  0.09719057
#   0.09759315  0.10541764  0.09822699  0.10414799]
# and [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112]
# [ 90  94 221  55 222 243  24 186 112 126]
# [0.01151389, 0.01163478, 0.013009299, 0.022521779, 0.024468875, 0.020641074, 0.015831618, 0.063118517, 0.16413645, 0.055943284]
# candidate: 90 score: 0.01947133243083954 word:all
# syllable count  2
# adjucted score:  0.0036945054307
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  2
# adjucted score:  0.00373329596786
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00417434292601
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00722664853401
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00785142048154
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00662317948107
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00507995113073
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0202530778062
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0214635823607
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0179507335407
# scores:  [ 0.00369451  0.0037333   0.00417434  0.00722665  0.00785142  0.00662318
#   0.00507995  0.02025308  0.02146358  0.01795073]
# softmax scores:  [ 0.09693464  0.09695344  0.09716748  0.09866178  0.09897047  0.09836453
#   0.09760846  0.10530172  0.105941    0.10409647]
# will [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112]
# [147  94 221 222  55  24 126 243 186 112]
# [0.010652408, 0.011572288, 0.01267949, 0.023671009, 0.023539355, 0.015589743, 0.05392791, 0.021489464, 0.060888164, 0.16232225]
# candidate: 147 score: 0.0033326013945043087 word:``
# syllable count  1
# adjucted score:  0.00139298023268
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  2
# adjucted score:  0.00371324400497
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00406851607702
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00759540622349
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00755316202709
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00500233987387
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0173040526571
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00689540564653
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0195374157796
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0212263452223
# scores:  [ 0.00139298  0.00371324  0.00406852  0.00759541  0.00755316  0.00500234
#   0.01730405  0.00689541  0.01953742  0.02122635]
# softmax scores:  [ 0.09600577  0.09712605  0.09729874  0.09902977  0.09900885  0.0977541
#   0.10395558  0.09868377  0.10512294  0.10601443]
# the [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112]
# [147  94 243 221  24 222  55 112 126 186]
# [0.010881579, 0.011495118, 0.022133902, 0.01241798, 0.015399957, 0.02301619, 0.024369506, 0.16128536, 0.052126952, 0.059110664]
# candidate: 147 score: 0.0033326013945043087 word:``
# syllable count  1
# adjucted score:  0.00142294810852
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  2
# adjucted score:  0.00368848207207
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00710218889905
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00398460443963
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00494144257058
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00738529213374
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00781953576868
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0210907535848
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.016726172419
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.018967062648
# scores:  [ 0.00142295  0.00368848  0.00710219  0.0039846   0.00494144  0.00738529
#   0.00781954  0.02109075  0.01672617  0.01896706]
# softmax scores:  [ 0.0960787   0.09717324  0.09884608  0.09731722  0.09778392  0.0989861
#   0.09920125  0.10600717  0.10371884  0.10488749]
# of [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112]
# [192  94  55 126 222  24 112 243 221 186]
# [0.011092261, 0.011510581, 0.024812359, 0.051096287, 0.022687728, 0.015278068, 0.16068059, 0.022408644, 0.012197244, 0.058066413]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  1
# adjucted score:  0.00145049841089
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  2
# adjucted score:  0.00369344366283
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.00796163575193
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0163954590707
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00727989710421
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00490233168016
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  1
# adjucted score:  0.0210116706416
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00719034641258
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00391377588622
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0186319898655
# scores:  [ 0.0014505   0.00369344  0.00796164  0.01639546  0.0072799   0.00490233
#   0.02101167  0.00719035  0.00391378  0.01863199]
# softmax scores:  [ 0.09612701  0.09721112  0.09930799  0.10358527  0.09897005  0.09780048
#   0.10600393  0.09892575  0.09731827  0.10475013]
#
#  [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112]
# [192  94  55 126 222  24 112 243 221 186]
# [0.011207309, 0.01154844, 0.025002595, 0.0505489, 0.022564488, 0.015184321, 0.16031082, 0.022494674, 0.012033922, 0.057487089]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  0
# adjucted score:  0.000790476020485
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  1
# adjucted score:  0.00151015137551
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  1
# adjucted score:  0.00326950682326
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  1
# adjucted score:  0.00661011278817
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  1
# adjucted score:  0.0029506835526
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  1
# adjucted score:  0.00198560359368
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  0
# adjucted score:  0.0113070731901
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  1
# adjucted score:  0.00294155423205
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  1
# adjucted score:  0.00157363621418
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  1
# adjucted score:  0.00751739689685
# scores:  [ 0.00079048  0.00151015  0.00326951  0.00661011  0.00295068  0.0019856
#   0.01130707  0.00294155  0.00157364  0.0075174 ]
# softmax scores:  [ 0.09837301  0.09872763  0.09959995  0.10127754  0.0994413   0.09896261
#   0.10368417  0.09943676  0.09875898  0.10173802]
#
#  [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112 112]
# [192  94  55 126 222  24 112 243 221 186]
# [0.011262746, 0.011577794, 0.025085973, 0.050238237, 0.022527715, 0.015109215, 0.16009463, 0.022513308, 0.01192482, 0.057163201]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  0
# adjucted score:  0.000794386111825
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  1
# adjucted score:  0.00151398994778
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  1
# adjucted score:  0.00328040983481
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  1
# adjucted score:  0.00656948839561
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  1
# adjucted score:  0.00294587495501
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  1
# adjucted score:  0.00197578216341
# candidate: 112 score: 0.028467116877436638 word:
#
# adjucted score:  1000.0
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  1
# adjucted score:  0.00294399092591
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  1
# adjucted score:  0.00155936935211
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  1
# adjucted score:  0.00747504314339
# scores:  [  7.94386112e-04   1.51398995e-03   3.28040983e-03   6.56948840e-03
#    2.94587496e-03   1.97578216e-03   1.00000000e+03   2.94399093e-03
#    1.55936935e-03   7.47504314e-03]
# softmax scores:  [  0.   0.   0.   0.   0.   0.  nan   0.   0.   0.]
# '' [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112 112 112]
# [192  94 221  24 243 222 126  55 186 112]
# [0.011290753, 0.011596413, 0.011854368, 0.015051474, 0.022511797, 0.022523075, 0.050051022, 0.0251287, 0.056979258, 0.15997306]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  0
# adjucted score:  0.000796361553687
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  1
# adjucted score:  0.00151642469307
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  1
# adjucted score:  0.00155015660816
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  1
# adjucted score:  0.0019682315545
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  1
# adjucted score:  0.00294379338905
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  1
# adjucted score:  0.00294526821726
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  1
# adjucted score:  0.00654500697812
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  1
# adjucted score:  0.00328599713195
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  1
# adjucted score:  0.00745098943826
# candidate: 112 score: 0.028467116877436638 word:
#
# adjucted score:  1000.0
# scores:  [  7.96361554e-04   1.51642469e-03   1.55015661e-03   1.96823155e-03
#    2.94379339e-03   2.94526822e-03   6.54500698e-03   3.28599713e-03
#    7.45098944e-03   1.00000000e+03]
# softmax scores:  [  0.   0.   0.   0.   0.   0.   0.   0.   0.  nan]
# ''
# /home/trevor/anaconda3/envs/nntest/lib/python3.5/site-packages/ipykernel/__main__.py:76: RuntimeWarning: overflow encountered in exp
# /home/trevor/anaconda3/envs/nntest/lib/python3.5/site-packages/ipykernel/__main__.py:77: RuntimeWarning: invalid value encountered in true_divide
# /home/trevor/anaconda3/envs/nntest/lib/python3.5/site-packages/ipykernel/__main__.py:41: RuntimeWarning: invalid value encountered in less
# [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112 112 112 112]
# [192  94 221  24 243 222 126  55 186 112]
# [0.011305289, 0.011607205, 0.011809105, 0.015008667, 0.022505382, 0.022529777, 0.049934659, 0.025154717, 0.056874443, 0.15990965]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  0
# adjucted score:  0.000797386815437
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  1
# adjucted score:  0.00151783582721
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  1
# adjucted score:  0.0015442376878
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  1
# adjucted score:  0.00196263390555
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  1
# adjucted score:  0.00294295452723
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  1
# adjucted score:  0.00294614458916
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  1
# adjucted score:  0.00652979055077
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  1
# adjucted score:  0.00328939934506
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  1
# adjucted score:  0.00743728315705
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  0
# adjucted score:  0.0112787778576
# scores:  [ 0.00079739  0.00151784  0.00154424  0.00196263  0.00294295  0.00294614
#   0.00652979  0.0032894   0.00743728  0.01127878]
# softmax scores:  [ 0.09838688  0.09874194  0.09875497  0.09896178  0.09944804  0.09944963
#   0.10124765  0.09962046  0.1017081   0.10368054]
# '' [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112 112 112 112 112]
# [192  94 221  24 243 222 126  55 186 112]
# [0.011312989, 0.011613151, 0.011779944, 0.014977635, 0.022498831, 0.022539595, 0.049861714, 0.025172483, 0.056815233, 0.15987916]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  0
# adjucted score:  0.000797929859958
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  1
# adjucted score:  0.00151861343069
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  1
# adjucted score:  0.00154042444701
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  1
# adjucted score:  0.00195857587495
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  1
# adjucted score:  0.00294209788466
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  1
# adjucted score:  0.00294742845695
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  1
# adjucted score:  0.00652025178576
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  1
# adjucted score:  0.0032917225344
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  1
# adjucted score:  0.00742954049166
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  0
# adjucted score:  0.011276627488
# scores:  [ 0.00079793  0.00151861  0.00154042  0.00195858  0.0029421   0.00294743
#   0.00652025  0.00329172  0.00742954  0.01127663]
# softmax scores:  [ 0.09838831  0.09874348  0.09875425  0.09896094  0.09944879  0.09945144
#   0.10124401  0.09962279  0.10170536  0.10368064]
#
#  [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112 112 112 112 112 112]
# [192  94 221  24 243 222 126  55 186 112]
# [0.011317011, 0.011616039, 0.011760969, 0.014955339, 0.022493437, 0.022549544, 0.049816068, 0.025185341, 0.056782853, 0.1598669]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  0
# adjucted score:  0.000798213567383
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  1
# adjucted score:  0.00151899108901
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  1
# adjucted score:  0.00153794305769
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  1
# adjucted score:  0.00195566031861
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  1
# adjucted score:  0.00294139250027
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  1
# adjucted score:  0.00294872937478
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  1
# adjucted score:  0.00651428281136
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  1
# adjucted score:  0.00329340391162
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  1
# adjucted score:  0.00742530623674
# candidate: 112 score: 0.028467116877436638 word:
#
# syllable count  0
# adjucted score:  0.0112757625056
# scores:  [ 0.00079821  0.00151899  0.00153794  0.00195566  0.00294139  0.00294873
#   0.00651428  0.0032934   0.00742531  0.01127576]
# softmax scores:  [ 0.09838912  0.09874434  0.0987537   0.09896017  0.09944911  0.09945276
#   0.10124168  0.09962431  0.1017039   0.1036809 ]
# and [164 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112 112
#  112 112 112 112 112 112 112 112 112 112 112 112]
# [192  94 221  24 243 222 126  55 186 112]
# [0.011319301, 0.011617357, 0.011748578, 0.014939505, 0.022489361, 0.022558222, 0.049787607, 0.025195062, 0.056766201, 0.15986289]
# candidate: 192 score: 0.005790697876363993 word:''
# syllable count  1
# adjucted score:  0.0014801876404
# candidate: 94 score: 0.0022112438455224037 word:but
# syllable count  2
# adjucted score:  0.00372770532521
# candidate: 221 score: 0.002327405381947756 word:will
# syllable count  2
# adjucted score:  0.00376981086124
# candidate: 24 score: 0.01619320921599865 word:of
# syllable count  2
# adjucted score:  0.00479369546449
# candidate: 243 score: 0.006178884766995907 word:and
# syllable count  2
# adjucted score:  0.00721624661562
# candidate: 222 score: 0.01168826874345541 word:it
# syllable count  2
# adjucted score:  0.00723834202594
# candidate: 126 score: 0.01395866647362709 word:i
# syllable count  2
# adjucted score:  0.0159755380957
# candidate: 55 score: 0.002779116854071617 word:in
# syllable count  2
# adjucted score:  0.0080844350485
# candidate: 186 score: 0.01859152503311634 word:the
# syllable count  2
# adjucted score:  0.0182147859164
# candidate: 112 score: 0.028467116877436638 word:
#
# adjucted score:  1000.0
# scores:  [  1.48018764e-03   3.72770533e-03   3.76981086e-03   4.79369546e-03
#    7.21624662e-03   7.23834203e-03   1.59755381e-02   8.08443505e-03
#    1.82147859e-02   1.00000000e+03]
# softmax scores:  [  0.   0.   0.   0.   0.   0.   0.   0.   0.  nan]
# "will me all cries i i immortal immortal enemy warning us is in of you the and you will and will the of \n \n '' '' '' \n and ''"

# %% [markdown]
# ## Text Generation

# %%
# begin with some random characters and predict the next n characters

def generate_text(model, length):
    # generate a number and associated character
    ix = [np.random.randint(num_features)]
    print("ix: ", ix)
    y_char = [ix_to_char[ix[-1]]]
    # annoyingly, the big matrix of character sequences is called X
    X = np.zeros((1, length, num_features))
    
    for i in range(length):
        # for n characters
        # update the big matrix with the last prediction
        X[0, i, :][ix[-1]] = 1
        # print the last prediction to the command line
        print(ix_to_char[ix[-1]], end=" ")
        # get a new prediction
        # I don't know what most of these arguments are. 
        # I don't understand why the prediction needs to be subscripted
        # I guess the 1 means that you only get one output from argmax? 
        # return np.argmax(model.predict(X[:, :i+1, :])[0], 1)

        
        # to use other methods from the heuristic section, change this line.
        ix = beam_search(model.predict(X[:, :i+1, :]), y_char, i)

        
        # convert to character and append to array
        y_char.append(ix_to_char[ix[-1]])
    
    return (' ').join(y_char)

# %% [markdown]
# ## Training

# %%
# I don't know if nb is supposed to mean something. This is just a counter


if len(sys.argv) > 1:
    model.load_weights(sys.argv[1])
    print(re.findall(r'epoch(\d)', sys.argv[1]))
    nb_epoch = int(re.findall(r'epoch(\d+)', sys.argv[1])[0])
    print("Using weights in {}".format(sys.argv[1]))
    print("epoch: {}".format(nb_epoch)) 
else:
    print("Using a new model")
    nb_epoch = 0
batch_size = 40
generate_length = 100
epoch_per_gen = 10

while True:
    print("\n\n")
    # fit the model for one epoch
    model.fit(X, y, batch_size=batch_size, verbose=1, nb_epoch=epoch_per_gen)
    # increment counter
    nb_epoch += epoch_per_gen
    # every epoch, show some text examples.
    # this is a function defined below.
    generate_text(model, generate_length)
    
    if nb_epoch % epoch_per_gen*10 == 0:
        # save every tenth epoch group
        print("epoch # {}".format(nb_epoch))
        generate_text(model, generate_length)
        model.save_weights('checkpoints/checkpoint_{}_epoch{}.hdf5'.format(hidden_dim, nb_epoch))
# Out:
# Epoch 1/1
# 265/265 [==============================] - 91s - loss: 5.5687
# whispers
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1bfb603c3ae9> in <module>()
#      13     # every epoch, show some text examples.
#      14     # this is a function defined below.
# ---> 15     generate_text(model, generate_length)
#      16
#      17     if nb_epoch % 10 == 0:
#
# <ipython-input-14-85cd4702326f> in generate_text(model, length)
#      18         # I don't understand why the prediction needs to be subscripted
#      19         # I guess the 1 means that you only get one output from argmax?
# ---> 20         ix = selct_best(model.predict(X[:, :i+1, :]), X, i)
#      21
#      22         # convert to character and append to array
#
# NameError: name 'selct_best' is not defined
