# %% [markdown]
# ## Initializing stuff

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, SimpleRNN
from keras.layers.wrappers import TimeDistributed
import numpy as np

# I'm making this from Trung Tran's LSTM tutorial. 
# I'm going to try to annotate it in my own words so that I can understand what's happening
# And then change it to do what I want. 

data = ['i', ' ', 'h', 'a', 'v', 'e', ' ', 'a', ' ', 'd', 'r', 'e', 'a', 'm']

# features. This will eventually be words
chars = list(set(data))

# %% [markdown]
# ## Preparing data

# %%
# conversion to numbers. This is actually a really clever solution
ix_to_char = {ix:char for ix, char in enumerate(chars)}
char_to_ix = {char:ix for ix, char in enumerate(chars)}

# setting up parameters. 
num_features = len(chars)
# length of the group of words that the lstm will be shown at a time
len_sequence = 3
num_sequences = len(data)//len_sequence


# need input and output tapes for the LSTM
X = np.zeros((len(data)//len_sequence, len_sequence, num_features))
y = np.zeros((len(data)//len_sequence, len_sequence, num_features))

# for each of the sequences
for i in range(0, len(data)//len_sequence):
    # select the characters in the data that correspond to this sequence
    X_sequence = data[i*len_sequence:(i+1)*len_sequence]
    # convert to numeric
    X_sequence_ix = [char_to_ix[value] for value in X_sequence]
    #initialize 
    input_sequence = np.zeros((len_sequence, num_features))
    for j in range(len_sequence):
        #make a 1-hot vector for each of the letters the lstm is being shown
        input_sequence[j][X_sequence_ix[j]] = 1

    X[i] = input_sequence
    
    # select targets: the symbol that follows
    y_sequence = data[i*len_sequence+1:(i+1)*len_sequence+1]
    # convert to numeric
    y_sequence_ix = [char_to_ix[value] for value in y_sequence]
    target_sequence = np.zeros((len_sequence, num_features))
    for j in range(len_sequence):
        target_sequence[j][y_sequence_ix[j]] = 1
        
    y[i] = target_sequence

# %% [markdown]
# ## Setting up network

# %%
# initialize a sequential network
model = Sequential()

hidden_dim = 500
layer_num = 2

# add an initial lstm layer
# I don't know why the input shape needs to be a tuple
# the return-sequences parameter makes it give you multiple outputs
model.add(LSTM(hidden_dim, input_shape=(None, num_features), return_sequences=True))

# add more layers
# I don't really know what adding a layer to an LSTM means, 
#  they're only ever shown with one.

for i in range(layer_num-1):
    model.add(LSTM(hidden_dim, return_sequences=True))

# I don't see why the dense layer is necessary, but Tran says it is.
# and in order to get the dense layer to work, a time distributed layer
#  needs to go between.

model.add(TimeDistributed(Dense(num_features)))

# pick an activation for this layer
model.add(Activation('softmax'))

# pick a loss function and optimization method. 

model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %% [markdown]
# ## Training

# %%
# I don't know if nb is supposed to mean something. This is just a counter

nb_epoch = 0
batch_size = 50
generate_length = 50

while True:
    print("\n\n")
    # fit the model for one epoch
    model.fit(X, y, batch_size=batch_size, verbose=1, nb_epoch=10)
    # increment counter
    nb_epoch += 1
    # every epoch, show some text examples.
    # this is a function defined below.
#     generate_text(model, generate_length)
    
    if nb_epoch % 10 == 0:
        # save every tenth epoch
        print("epoch # {}".format(nb_epoch*10))
        generate_text(model, generate_length)
        model.save_weights('checkpoint_{}_epoch{}.hdf5'.format(hidden_dim, nb_epoch))
# Out:
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.6606
# daaaaaa
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.4623
# haa  ddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.3379
# a   dddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.2455
# ve  dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.1733
# ae       dddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.1152
# ea ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.0972
# deeaaaaaaadddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.0031
# vee addddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.9260
# heaaaddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.8762
# ha aaddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.8615
# aee   dddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.7937
# ae  dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.7813
# heaaaddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.7227
# deeaaaaaaaaaaadddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.6965
#    ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.6705
# deeaaaaaaaaadddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.6477
# ihhaaaaaaaaadddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.6256
# he aaddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.6046
#    ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.5817
# m   dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.5599
# vee addddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.5383
# i haaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.5165
# h aadddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.4946
# ave   dddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.4723
# ave  ddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.4499
# i haaaaaaadddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.4271
# e  adddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.4040
# dreaaaaaaaaaaadddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.3807
# dreaaaaaaaaaaadddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.3571
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.3336
# m  adddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.3099
# h aadddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.2867
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.2638
# ve  addddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.2416
# m  adddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.2203
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1999
# e aadddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1807
# e aadddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1626
# vve aaaddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1457
# i haaaaaaaaaaaaddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1303
# dreaaaaaaaaaaaaaaddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1161
# vve aaaddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.1033
# dreaaaaaaaaaaaaaaadddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0918
# vve aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0816
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0724
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0643
# dreaaaaaaaaaaaaaaaaddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0572
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0509
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0454
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0405
# dreaaaaaaaaaaaaaaadddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0362
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0324
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0291
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0262
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0236
# vv  aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0213
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0192
# vv  aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0174
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0158
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0144
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0131
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0119
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0108
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0099
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0091
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0083
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0076
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0070
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0064
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0059
# dreaaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0054
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0050
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0046
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0042
# vv  aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0039
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0036
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0033
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0031
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0028
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0026
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0024
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0023
#  a ddddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0021
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0019
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0018
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0017
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0016
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0015
# i haaaaaaaaaaaaadddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0013
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0013
# m a dddddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0012
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0011
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 0.0010
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 9.4206e-04
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 8.7776e-04
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 8.1810e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 7.6275e-04
# i haaaaaaaaaaaaddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 7.1129e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 6.6356e-04
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 6.1917e-04
# dreaaaaaaaaaaaaddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 5.7786e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 5.3944e-04
# dreaaaaaaaaaaaaddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 5.0375e-04
# i haaaaaaaaaaaaddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 4.7052e-04
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 4.3959e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 4.1073e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 3.8386e-04
# mav aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 3.5887e-04
# mav aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 3.3552e-04
# dreaaaaaaaaaaaaddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 3.1383e-04
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 2.9355e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 2.7464e-04
# dreaaaaaaaaaaadddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 2.5702e-04
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 2.4056e-04
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 2.2522e-04
# dreaaaaaaaaaaadddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 2.1085e-04
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.9746e-04
# ha  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.8494e-04
# dreaaaaaaaaaaadddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.7326e-04
# mav aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.6236e-04
# ea  aadddddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.5214e-04
# ave  aaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.4260e-04
# rv aaaaaaddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.3370e-04
# mav aaaadddddddddddddddddddddddddddddddddddddddddd
#
#
# Epoch 1/1
# 4/4 [==============================] - 0s - loss: 1.2534e-04
# i haaaaaaaaaaaadddddddddddddddd

# %% [markdown]
# ## Text Generation

# %%
# begin with some random characters and predict the next n characters

def generate_text(model, length):
    # generate a number and associated character
    ix = [np.random.randint(num_features)]
    y_char = [ix_to_char[ix[-1]]]
    # annoyingly, the big matrix of character sequences is called X
    X = np.zeros((1, length, num_features))
    
    for i in range(length):
        # for n characters
        # update the big matrix with the last prediction
        X[0, i, :][ix[-1]] = 1
        # print the last prediction to the command line
        print(ix_to_char[ix[-1]], end="")
        # get a new prediction
        # I don't know what most of these arguments are. 
        # I don't understand why the prediction needs to be subscripted
        # I guess the 1 means that you only get one output from argmax? 
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        
        # convert to character and append to array
        y_char.append(ix_to_char[ix[-1]])
    
    return ('').join(y_char)
